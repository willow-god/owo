# %%
import requests
import os

# 文件链接列表
# 文件链接列表
urls = [
    "https://npm.elemecdn.com/blobcat@1.0.0/ablobcatheart.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/ablobcatheartbroken.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatheartpride.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatlove.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatkissheart.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatsnuggle.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatcomfy.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatcomftears.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatfacepalm.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcat0_0.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatangry.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatblush.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatcoffee.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatcry.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatdeath.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatdisturbed.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatfearful.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatfingerguns.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatflip.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatflower.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatgay.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatneutral.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatopenmouth.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatsadreach.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatscared.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatnomblobcat.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatpresentred.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatread.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatsipsweat.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatsnapped.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatthink.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcattriumph.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatumm.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatverified.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatbox.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatcaged.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatgooglytrash.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatheadphones.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcathighfive.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatmelt.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatmeltthumb.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatnotlikethis.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatsaitama.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatyandere.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatpeek2.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatpeekaboo.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatphoto.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/ablobcatattentionreverse.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/ablobcatreachrev.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/ablobcatwave.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatalt.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatpolice.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/blobcatshocked.png",
    "https://npm.elemecdn.com/blobcat@1.0.0/ablobcatrainbow.png"
]

# 保存文件的目标文件夹
target_folder = "blobcat"
os.makedirs(target_folder, exist_ok=True)

# 设置新的前缀
new_prefix = ""

# 下载文件
for url in urls:
    # 获取原始文件名
    original_file_name = os.path.basename(url)
    
    # # 查找原始前缀的结尾位置
    # underscore_index = original_file_name
    
    # # 如果找到下划线，替换前缀
    # if underscore_index != -1:
    #     # 获取原始前缀的部分之后的文件名
    #     original_suffix = original_file_name[underscore_index:]
    #     # 构造新的文件名
    #     new_file_name = new_prefix + original_suffix[1:]
    # else:
    #     # 如果没有找到下划线，则直接添加新的前缀
    #     new_file_name = new_prefix + original_file_name
    
    # 生成文件保存路径
    file_path = original_file_name
    
    # 请求下载文件
    response = requests.get(url)
    
    # 检查响应状态
    if response.status_code == 200:
        # 保存文件
        with open(file_path, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded: {file_path}")
    else:
        print(f"Failed to download: {url}")

print("All files downloaded.")
# Out:
# Downloaded: ablobcatheart.png
# Downloaded: ablobcatheartbroken.png
# Downloaded: blobcatheartpride.png
# Downloaded: blobcatlove.png
# Downloaded: blobcatkissheart.png
# Downloaded: blobcatsnuggle.png
# Downloaded: blobcatcomfy.png
# Downloaded: blobcatcomftears.png
# Downloaded: blobcatfacepalm.png
# Downloaded: blobcat0_0.png
# Downloaded: blobcatangry.png
# Downloaded: blobcatblush.png
# Downloaded: blobcatcoffee.png
# Downloaded: blobcatcry.png
# Downloaded: blobcatdead.png
# Downloaded: blobcatdisturbed.png
# Downloaded: blobcatfearful.png
# Downloaded: blobcatfingerguns.png
# Downloaded: blobcatflip.png
# Downloaded: blobcatflower.png
# Downloaded: blobcatgay.png
# Downloaded: blobcatneutral.png
# Downloaded: blobcatopenmouth.png
# Downloaded: blobcatsadreach.png
# Downloaded: blobcatscared.png
# Downloaded: blobcatnomblobcat.png
# Downloaded: blobcatpresentred.png
# Downloaded: blobcatread.png
# Downloaded: blobcatsipsweat.png
# Downloaded: blobcatsnapped.png
# Downloaded: blobcatthink.png
# Downloaded: blobcattriumph.png
# Downloaded: blobcatumm.png
# Downloaded: blobcatverified.png
# Downloaded: blobcatbox.png
# Downloaded: blobcatcaged.png
# Downloaded: blobcatgooglytrash.png
# Downloaded: blobcatheadphones.png
# Downloaded: blobcathighfive.png
# Downloaded: blobcatmelt.png
# Downloaded: blobcatmeltthumb.png
# Downloaded: blobcatnotlikethis.png
# Downloaded: blobcatsaitama.png
# Downloaded: blobcatyandere.png
# Downloaded: blobcatpeek2.png
# Downloaded: blobcatpeekaboo.png
# Downloaded: blobcatphoto.png
# Downloaded: ablobcatattentionreverse.png
# Downloaded: ablobcatreachrev.png
# Downloaded: ablobcatwave.png
# Downloaded: blobcatalt.png
# Downloaded: blobcatpolice.png
# Downloaded: blobcatshocked.png
# Downloaded: ablobcatrainbow.png
# All files downloaded.

# %%
# 给文件夹下/catbug/下的所有webp文件添加前缀”catbug-“
import os
import shutil

target_folder = "catbug"
new_prefix = "catbug-"

# 遍历文件夹
for root, dirs, files in os.walk(target_folder):
    for file in files:
        # 检查文件扩展名
        if file.endswith(".webp"):
            # 生成文件路径
            file_path = os.path.join(root, file)
            # 生成新的文件路径
            new_file_path = os.path.join(root, new_prefix + file)
            # 重命名文件
            os.rename(file_path, new_file_path)
            print(f"Renamed: {file_path} -> {new_file_path}")
            
print("All files renamed.")
# Out:
# Renamed: catbug\不准色色.webp -> catbug\catbug-不准色色.webp
# Renamed: catbug\不要.webp -> catbug\catbug-不要.webp
# Renamed: catbug\不要呀.webp -> catbug\catbug-不要呀.webp
# Renamed: catbug\亲亲.webp -> catbug\catbug-亲亲.webp
# Renamed: catbug\亲脸.webp -> catbug\catbug-亲脸.webp
# Renamed: catbug\偷偷看.webp -> catbug\catbug-偷偷看.webp
# Renamed: catbug\偷偷给心.webp -> catbug\catbug-偷偷给心.webp
# Renamed: catbug\再见.webp -> catbug\catbug-再见.webp
# Renamed: catbug\吃掉你.webp -> catbug\catbug-吃掉你.webp
# Renamed: catbug\吹风.webp -> catbug\catbug-吹风.webp
# Renamed: catbug\呕吼.webp -> catbug\catbug-呕吼.webp
# Renamed: catbug\和我色色.webp -> catbug\catbug-和我色色.webp
# Renamed: catbug\咬你.webp -> catbug\catbug-咬你.webp
# Renamed: catbug\开心.webp -> catbug\catbug-开心.webp
# Renamed: catbug\思考中.webp -> catbug\catbug-思考中.webp
# Renamed: catbug\扭一扭.webp -> catbug\catbug-扭一扭.webp
# Renamed: catbug\扭屁股.webp -> catbug\catbug-扭屁股.webp
# Renamed: catbug\摇摇晃晃.webp -> catbug\catbug-摇摇晃晃.webp
# Renamed: catbug\无奈.webp -> catbug\catbug-无奈.webp
# Renamed: catbug\棒.webp -> catbug\catbug-棒.webp
# Renamed: catbug\点赞.webp -> catbug\catbug-点赞.webp
# Renamed: catbug\爱你.webp -> catbug\catbug-爱你.webp
# Renamed: catbug\爱你2.webp -> catbug\catbug-爱你2.webp
# Renamed: catbug\牛.webp -> catbug\catbug-牛.webp
# Renamed: catbug\生气.webp -> catbug\catbug-生气.webp
# Renamed: catbug\睡觉.webp -> catbug\catbug-睡觉.webp
# Renamed: catbug\耍帅.webp -> catbug\catbug-耍帅.webp
# Renamed: catbug\脸红.webp -> catbug\catbug-脸红.webp
# Renamed: catbug\膜拜.webp -> catbug\catbug-膜拜.webp
# Renamed: catbug\舔屏.webp -> catbug\catbug-舔屏.webp
# Renamed: catbug\贴贴.webp -> catbug\catbug-贴贴.webp
# Renamed: catbug\问号.webp -> catbug\catbug-问号.webp
# All files renamed.

# %%
import json
import requests
from bs4 import BeautifulSoup
import os

# 假设json_data是包含上述JSON数据的字符串
json_data = '''
{
  "胆小鬼": {
    "type": "image",
    "container": [
      {
        "icon": "https://expression.qjqq.cn/1/663c6390ccf24.webp",
        "text": "death-搬砖"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6390cce3d.webp",
        "text": "death-报告"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6390cc7fb.webp",
        "text": "death-悲伤眼泪"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6391e8702.webp",
        "text": "death-呆萌"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6391e879b.webp",
        "text": "death-发抖"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6391e8e91.webp",
        "text": "death-奔跑"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6420bb399.webp",
        "text": "death-孤独"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6420bbb49.webp",
        "text": "death-孤独寂寞"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6420bbb64.webp",
        "text": "death-害怕"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6421b64c0.webp",
        "text": "death-坏笑"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6421a8114.webp",
        "text": "death-黑脸"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6421a9c7d.webp",
        "text": "death-黑线"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c642293552.webp",
        "text": "death-可怜无助"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6422a1c39.webp",
        "text": "death-空洞呆"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6422a9f11.webp",
        "text": "death-难过"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6423865fb.webp",
        "text": "death-谁也不爱"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c642374a88.webp",
        "text": "death-弱小无助"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6423a4209.webp",
        "text": "death-生气"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c642457735.webp",
        "text": "death-死神驾到"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6424817ab.webp",
        "text": "death-死神施法"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c642483aca.webp",
        "text": "death-死神巫师"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c64255054a.webp",
        "text": "death-逃跑"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c642566bb9.webp",
        "text": "death-痛苦无助"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c6425a0801.webp",
        "text": "death-吓人"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c642623ba2.webp",
        "text": "death-嫌弃讨厌"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c642659691.webp",
        "text": "death-邪恶的笑"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c642693027.webp",
        "text": "death-心痛"
      },
      {
        "icon": "https://expression.qjqq.cn/1/663c64272fd9e.webp",
        "text": "death-摘下面具"
      }
    ]
  }
}
'''

# 将JSON字符串解析为Python字典
data = json.loads(json_data)

# 指定下载图片的文件夹
download_folder = 'death'
if not os.path.exists(download_folder):
    os.makedirs(download_folder)

# 遍历JSON数据中的图片链接
for item in data["胆小鬼"]["container"]:
    text = item["text"]  # 获取text字段
    icon = item["icon"]  # 获取icon字段
    img_url = icon
    
    # 构造新的文件名
    filename = f'{text}.png'
    
    print(f'正在下载图片: {img_url}')
    
    # 确保文件名不包含非法字符
    filename = filename.replace('/', '-').replace('\\', '-')
    
    # 拼接完整的文件路径
    file_path = os.path.join(download_folder, filename)
    
    # 发送HTTP请求下载图片
    response = requests.get(img_url)
    if response.status_code == 200:
        # 打开文件并写入内容
        with open(file_path, 'wb') as file:
            file.write(response.content)
        print(f'图片已下载: {file_path}')
    else:
        print(f'图片下载失败: {img_url}')

print('所有图片下载完成。')
# Out:
# 正在下载图片: https://expression.qjqq.cn/1/663c6390ccf24.webp
# 图片已下载: death\death-搬砖.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6390cce3d.webp
# 图片已下载: death\death-报告.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6390cc7fb.webp
# 图片已下载: death\death-悲伤眼泪.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6391e8702.webp
# 图片已下载: death\death-呆萌.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6391e879b.webp
# 图片已下载: death\death-发抖.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6391e8e91.webp
# 图片已下载: death\death-奔跑.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6420bb399.webp
# 图片已下载: death\death-孤独.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6420bbb49.webp
# 图片已下载: death\death-孤独寂寞.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6420bbb64.webp
# 图片已下载: death\death-害怕.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6421b64c0.webp
# 图片已下载: death\death-坏笑.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6421a8114.webp
# 图片已下载: death\death-黑脸.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6421a9c7d.webp
# 图片已下载: death\death-黑线.png
# 正在下载图片: https://expression.qjqq.cn/1/663c642293552.webp
# 图片已下载: death\death-可怜无助.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6422a1c39.webp
# 图片已下载: death\death-空洞呆.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6422a9f11.webp
# 图片已下载: death\death-难过.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6423865fb.webp
# 图片已下载: death\death-谁也不爱.png
# 正在下载图片: https://expression.qjqq.cn/1/663c642374a88.webp
# 图片已下载: death\death-弱小无助.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6423a4209.webp
# 图片已下载: death\death-生气.png
# 正在下载图片: https://expression.qjqq.cn/1/663c642457735.webp
# 图片已下载: death\death-死神驾到.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6424817ab.webp
# 图片已下载: death\death-死神施法.png
# 正在下载图片: https://expression.qjqq.cn/1/663c642483aca.webp
# 图片已下载: death\death-死神巫师.png
# 正在下载图片: https://expression.qjqq.cn/1/663c64255054a.webp
# 图片已下载: death\death-逃跑.png
# 正在下载图片: https://expression.qjqq.cn/1/663c642566bb9.webp
# 图片已下载: death\death-痛苦无助.png
# 正在下载图片: https://expression.qjqq.cn/1/663c6425a0801.webp
# 图片已下载: death\death-吓人.png
# 正在下载图片: https://expression.qjqq.cn/1/663c642623ba2.webp
# 图片已下载: death\death-嫌弃讨厌.png
# 正在下载图片: https://expression.qjqq.cn/1/663c642659691.webp
# 图片已下载: death\death-邪恶的笑.png
# 正在下载图片: https://expression.qjqq.cn/1/663c642693027.webp
# 图片已下载: death\death-心痛.png
# 正在下载图片: https://expression.qjqq.cn/1/663c64272fd9e.webp
# 图片已下载: death\death-摘下面具.png
# 所有图片下载完成。
